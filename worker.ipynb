# %%
import pandas as pd

data = pd.read_parquet("pacote.parquet","pyarrow")
data.sample()
# Out:
#                                      pk           id  codigo qualificacao  \
# 9  debd0e9a-deaa-47a4-93b1-b4ba6cbd62e8  61462853749   75076       fisica
#
#                        nome   criado_em        atualizado_em  fornecedor  \
# 9  HELENA DA SILVA OLIVEIRA  2013-10-22  2023-01-12T12:18:37        True
#
#    vendedor  inativo                                           contatos  \
# 9     False    False  [{'atualizado_em': '2022-12-14T21:31:38', 'cpf...
#
#                                            enderecos contas_fornecedores
# 9  [{'atualizado_em': '2016-07-08T22:53:26', 'bai...                  []

# %%
json_data = data.to_json(
    orient="records",
    index=False, indent=True
)
json_data
# Out:
# '[\n {\n  "pk":"ff655f7c-d2f8-4cbb-806c-b04e32046ff6",\n  "id":27150648000109,\n  "codigo":73189,\n  "qualificacao":"juridica",\n  "nome":"15 OFICIO DE NOTAS DA COMARCA DA CAPITAL DO ESTADO DO RIO DE JANEIRO",\n  "criado_em":"2013-05-14",\n  "atualizado_em":"2023-01-12T12:18:37",\n  "fornecedor":true,\n  "vendedor":false,\n  "inativo":false,\n  "contatos":[\n   {\n    "atualizado_em":"2022-08-23T18:55:15",\n    "cpf":null,\n    "id":"af5b7368-a3f0-4ff3-91ea-e10a32c8b556",\n    "nascimento":null,\n    "nome":"ADRIANA OLIVEIRA",\n    "primeiro_nome":null,\n    "sexo":null,\n    "sobre_nome":null\n   },\n   {\n    "atualizado_em":"2022-08-23T18:55:15",\n    "cpf":null,\n    "id":"89642928-8e0c-4b22-a66b-b64654706c35",\n    "nascimento":null,\n    "nome":"CARTORIO FERNANDA DE FREITAS LEITAO",\n    "primeiro_nome":null,\n    "sexo":null,\n    "sobre_nome":null\n   },\n   {\n    "atualizado_em":"2022-08-23T18:55:15",\n    "cpf":null,\n    "id":"dc383592-bdfa-4d36-94a2-c1cfa3c5af8a",\n    "
# ...
